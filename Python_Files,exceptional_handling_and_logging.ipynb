# %% [markdown]
# # Theory Questions and Answers

# %% [markdown]
# 1.	What is the difference between interpreted and compiled languages?
#   - The main difference between interpreted and compiled languages lies in how the source code is executed. In compiled languages, the entire code is translated into machine code at once before execution, resulting in faster performance.
#  -	In interpreted languages, the code is executed line by line by an interpreter, offering more flexibility but potentially slower execution.

# %% [markdown]
# 2.	What is exception handling in python?
#    - Exception handling in Python is a mechanism that allows programs to gracefully manage and recover from runtime errors, known as exceptions, instead of crashing abruptly. When an unexpected event occurs during program execution, such as dividing by zero or attempting to access a non-existent file, Python raises an exception. If this exception is not handled, the program terminates.

# %% [markdown]
# 3.	What is the purpose of the finally block in exception handling?
#    - The finally block in exception handling ensures that a specific section of code is always executed, regardless of whether an exception is thrown or caught within the corresponding try block (and any associated catch blocks). It's primarily used for cleanup operations, such as closing files, releasing resources, or performing other essential actions that must occur regardless of the program's execution path.

# %% [markdown]
# 4.	What is logging in python?
#    - Python logging refers to the process of tracking events that occur while a software program is running. It is a fundamental practice in software development for debugging, troubleshooting, and monitoring the behavior and health of applications.
#    The Python standard library includes a built-in logging module that provides a flexible and powerful framework for generating and managing log messages. Instead of using simple print() statements for debugging, which can become cumbersome in larger applications, the logging module offers a structured approach to capturing information about program execution.

# %% [markdown]
# 5.	What is the significance of the __ del __ method in python?
#    - The __ del __ method in Python serves as a destructor. Its significance lies in providing a mechanism to perform cleanup actions when an object is about to be destroyed or garbage-collected.

# %% [markdown]
# 6.	What is the difference between import and from … import in python.?
#    - Both import module_name and from module_name import object_name(s) allow you to bring external code into your Python program, but they differ in how they affect the namespace and how you access the imported objects.

# %% [markdown]
# 7.	How can you handle multiple exceptions in python?
#    - Python, multiple exceptions can be handled within try-except blocks using   two primary methods:
#   -	Handling multiple exceptions with a single except block:
#   This approach is suitable when the same handling logic applies to different types of exceptions. The   exception types are specified as a tuple within the except clause.
#  - Handling different exceptions with multiple except blocks:
#    This method allows for specific handling logic for each exception type. Each except block targets a particular exception. The first except block that matches the raised exception will be executed.

# %% [markdown]
# 8.	What is the purpose of the with statement when handling files in pyhon?
#    - The with statement in Python, when used with file handling, serves the primary purpose of ensuring proper resource management and automatic cleanup, specifically the closing of the file.

# %% [markdown]
# 9.	What is the difference between multithreading and multiprocessing?
#    - Multithreading and multiprocessing are both techniques used to improve performance, but they differ in how they achieve this. Multithreading involves running multiple threads within a single process, sharing the same memory space, while multiprocessing involves running multiple processes, each with its own memory space, often on separate CPUs.

# %% [markdown]
# 10.	What are the advantages of using logging in a program?
#    - The benefits of using logging in a program are extensive and encompass various aspects of software development and operations.
#    - Here's a breakdown of the key advantages:
#    - Detailed information: Logs provide a record of events, variable values, function calls, and other contextual information that can be invaluable in understanding the sequence of events leading up to an error or unexpected behavior.
#    - Production issue resolution: In live environments, where directly interacting with a debugger isn't feasible, logs are often the only source of information to diagnose and resolve problems.
#    - Reduced time to resolution: By providing insights into the "where", "what", and "why" of an issue, logs help pinpoint the root cause more quickly, minimizing downtime and improving the user experience.

# %% [markdown]
# 11.	What is memory management in python?
#    - Memory management in Python refers to the automatic process by which Python handles the allocation and deallocation of memory resources during program execution. Unlike languages like C or C++ where developers manually manage memory, Python's memory manager takes care of these tasks automatically, simplifying development and reducing common memory-related errors.

# %% [markdown]
# 12.	What are the basic steps involved in exception handling in python?
#    - Python exception handling revolves around four main keywords: try, except, else, and finally.
#    Here's a breakdown of the basic steps involved:
#    - try block: Encloses the code that might potentially raise an exception.
#    - except block: Follows the try block and contains the code to handle specific types of exceptions that might occur within the try block. You can specify a particular exception type or use a general one to catch any exception.
#    - else block (optional): This block executes only if no exception is raised within the try block.
#    - finally block (optional): This block always executes, regardless of whether an exception is raised or not. It's often used for cleanup tasks like closing files or releasing resources.

# %% [markdown]
# 13.	Why is memory management important in python?
#    - Memory management is crucial in Python for several reasons, despite the language's automatic memory management features.
# Enhancing performance and preventing slowdowns
#
#  -	 Memory Leaks: If memory isn't properly released when objects are no longer needed, it can lead to memory leaks.
#
#  -	This results in a gradual build-up of unused memory, causing the application to consume excessive resources and slowing down its operations.
#  -	Resource Exhaustion: In extreme cases, unchecked memory leaks can exhaust available memory, potentially leading to application crashes or system instability.
#  -	This is particularly critical in long-running programs or those processing large datasets, where memory usage can continually escalate without proper management.
#  -	Optimize Performance: Efficient memory usage helps to maintain the performance of the application by ensuring that memory resources are used optimally and freed up when no longer needed.

# %% [markdown]
# 14.	What is the role of try and except in exception handling?
#    - The try and except blocks are fundamental components of exception handling in programming languages like Python. Their roles are as follows:
#   - try block:
# This block encloses the code that is anticipated to potentially raise an exception. It serves as a designated area where the program attempts to execute operations that might lead to errors. If no exception occurs within the try block, the execution proceeds normally.
#  - except block:
# This block is executed only if an exception is raised within the corresponding try block. It provides a mechanism to "catch" and handle specific types of exceptions or general exceptions. The code within the except block is designed to manage the error gracefully, preventing the program from crashing and allowing for alternative actions or error reporting. Multiple except blocks can be used to handle different types of exceptions specifically.
# In essence, the try block anticipates potential issues, while the except block provides the means to react to and recover from those issues, thereby enhancing the robustness and user-friendliness of the program.

# %% [markdown]
# 15.	How does python’s garbage collection system work?
#    - Python's garbage collection system automatically manages memory, freeing developers from manual memory deallocation. This system primarily relies on two techniques: reference counting and generational garbage collection.
#   - Reference counting
# Every object in Python has a reference count, indicating how many variables or other objects are pointing to it.
# When a reference is created (e.g., assigning an object to a variable or passing it to a function), the reference count increases.
# When a reference is removed or goes out of scope, the reference count decreases.
# Once an object's reference count drops to zero, it means it's no longer accessible by the program and can be safely deallocated, reclaiming the memory it occupies.
#  - Generational garbage collection
# While efficient, reference counting alone cannot handle situations involving cyclic references, where two or more objects reference each other, forming a loop. In such cases, the reference counts never drop to zero, leading to memory leaks.
# To address this, Python employs a generational garbage collector, which categorizes objects into three generations (Generation 0, 1, and 2) based on their age and likelihood of being garbage collected.
# Generation 0 contains newly created objects and is collected most frequently.
# Objects that survive a collection in Generation 0 are promoted to Generation 1, which is collected less frequently.
# Similarly, objects surviving Generation 1 are promoted to Generation 2, the oldest generation, collected least frequently.
# The generational garbage collector detects and cleans up these cyclic references by periodically examining objects in the older generations and using a "mark and sweep" algorithm to identify unreachable objects, regardless of their reference counts.

# %% [markdown]
# 16.	What is the purpose of the else block in exception handling?
#    - The purpose of the else block in exception handling (specifically in Python's try...except...else structure) is to execute code only if the try block completes successfully without raising any exceptions.
#    -	This allows for the separation of code that might cause an exception from code that should only run if the risky operation in the try block is successful, helping to avoid unintended catches. It enables conditional execution of actions when the try block runs without errors.
#   -	The else block executes after the try block has completed without errors but before the finally block, if one is present.

# %% [markdown]
# 17.	What are the common logging levels in python?
#   - The logging module in Python provides five standard logging levels, each representing a different severity of events:
#   - DEBUG (10): Detailed information, typically of interest only when diagnosing problems.
#   - INFO (20): Confirmation that things are working as expected.
#   - WARNING (30): An indication that something unexpected happened, or that a problem might occur in the near future (e.g., 'disk space low'). The software is still working as expected.
#   - ERROR (40): Due to a more serious problem, the software has not been able to perform some function.
#   - CRITICAL (50): A serious error, indicating that the program itself may be unable to continue running.

# %% [markdown]
# 18.	What is the difference between os. fork() and multiprocessing in python?
#    -  The core difference between os.fork() and Python's multiprocessing module lies in their level of abstraction and portability.
#  - os.fork():
# Low-level System Call:
# os.fork() is a direct wrapper around the Unix fork() system call. It creates a new process (child) that is an exact copy of the calling process (parent) at the moment of the fork.
#  - Copy-on-Write:
# It utilizes copy-on-write memory management, meaning physical memory pages are shared between parent and child until one process modifies them, at which point a copy is made.
#  - Platform-Specific:
# os.fork() is only available on POSIX-compliant systems (Linux, macOS, Unix-like). It is not supported on Windows.
#  - Manual Management:
# Inter-process communication and synchronization between parent and child processes created with os.fork() need to be handled manually using low-level mechanisms like pipes, shared memory, or signals.
# multiprocessing module:
#  - High-level Abstraction:
# The multiprocessing module provides a higher-level, more convenient API for creating and managing processes in Python. It abstracts away the complexities of system calls.
#  - Cross-Platform:
# It offers cross-platform compatibility, working on Windows, Linux, and macOS. On Windows, it typically uses a "spawn" method to create new processes, which involves starting a new Python interpreter instance.
#  - Built-in Tools:
# It includes various tools and classes for inter-process communication (Queues, Pipes), synchronization (Locks, Semaphores), and process management (Pools, Process objects).
#  - Start Methods:
# It supports different "start methods" for creating processes, including fork (default on Linux/Unix-like), spawn (default on Windows/macOS), and forkserver. The spawn method is generally safer and recommended for complex scenarios, especially when dealing with resources like CUDA.

# %% [markdown]
# 19.	What is the importance of closing a file in pyhon?
#   -  Here's why closing files is so important:
#  -	Data Integrity and Persistence: When you write data to a file in Python, the data is often stored in a temporary buffer in memory rather than immediately written to the disk. Closing the file explicitly forces the buffer to flush, meaning all data is physically written to the file, ensuring that your changes are saved and the file's data remains intact. Without proper closure, there's a risk of data loss, especially if the program or system crashes before the buffer is flushed.
#  -	Resource Management: Opening a file allocates system resources like memory and file handles. These resources are finite, and leaving files open can lead to "resource leaks," where these resources remain occupied unnecessarily. Over time, this can degrade system performance and potentially cause your program to crash.
#  -	File Locking and Access: Some operating systems lock files while they are open, preventing other programs or processes from accessing or modifying them. Closing a file releases these locks, allowing other programs to access it without issues.
#  -	Preventing Errors: Failure to close files can lead to errors like "Too many open files" if the number of open files exceeds the operating system's limit. Proper file closure helps avoid such errors and maintain the smooth execution of your program.
#  -	Code Maintainability and Robustness: Explicitly closing files makes your code more readable, maintainable, and robust. It clearly indicates when the program is done with the file resources, making it easier to understand and debug.

# %% [markdown]
# 20.	What is the difference between file.read() and file.readline() in python?
#    - In Python, both file.read() and file.readline() are methods used to read data from a file, but they differ in how they approach the task:
#  - file.read()
#  - Functionality: Reads the entire content of a file and returns it as a single string.
#  - Parameter: Takes an optional integer argument size, which specifies the number of characters or bytes to read from the file. If size is omitted or negative, the entire file is read.
#   - Return Value: Returns a string (or bytes if opened in binary mode) containing the file's content.
#   -	Use Cases: Ideal for reading small to medium-sized files where you want to process the entire content at once.
#   - file.readline()
#   -	Functionality: Reads a single line from the file at a time.
#   -	Parameter: Takes an optional integer argument size, which represents the maximum number of bytes to read from the line, including the trailing newline character.
#   -	Return Value: Returns a string containing the line read from the file. It returns an empty string when the end of the file is reached.
#   -	Use Cases: Particularly useful for processing large files line by line, or when you need to iterate and apply logic to each line individually.

# %% [markdown]
# 21.	What is the logging module in python used for?
#   - Logging in Python is a crucial practice in software development that allows tracking events, debugging issues, and monitoring the health and performance of applications. It provides a structured and flexible way to record information about a program's execution, offering significant advantages over simply using print() statements for debugging.

# %% [markdown]
# 22.	What is the os module in python used for in file handling?
#    - The os module in Python provides a way to interact with the operating system, offering a wide range of functions for file and directory manipulation, which are crucial for file handling.

# %% [markdown]
# 23.	What are the challenges associated with memory management in python?
#    - While Python's automatic memory management, primarily handled by reference counting and garbage collection, simplifies development, several challenges can arise in practice.
#  -	Memory leaks can occur when objects are no longer in use but remain referenced, preventing the garbage collector from reclaiming their memory.
#  -	A common cause is circular references where two or more objects reference each other, creating a cycle that the garbage collector may struggle to break.

# %% [markdown]
# 24.	How do you raise an exception manually in python?
#    - Python, exceptions are manually raised using the raise keyword. This allows developers to explicitly trigger an error condition at a specific point in the code, providing a mechanism for handling exceptional circumstances or enforcing validation rules.

# %% [markdown]
# 25.	Why is it important to use multithreading in certain applications?
#   - Multithreading is crucial for applications that require high performance, responsiveness, and efficient resource utilization. By allowing multiple tasks to run concurrently within a single process, multithreading can significantly improve execution speed, especially on multi-core processors. This is because threads can execute tasks simultaneously, overlapping their execution and reducing overall processing time.

# %% [markdown]
# # Practical Questions and Answers

# %% [markdown]
# 1.	How can you open a file for writing in python and write a string to it?

# %%
with open("my_file.txt", "w") as file:
  file.write("Hello, Python!")
print("File written successfully!")
# Out:
# File written successfully!

# %% [markdown]
# 2.	Write a python program to read the contents of a file and print each line?

# %%
def read_and_print_file(filename):

    try:
        with open(filename, 'r') as file:
            for line in file:
                print(line.strip())
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage:
if __name__ == "__main__":
    file_to_read = "my_document.txt"

    try:
        with open(file_to_read, 'w') as f:
            f.write("This is the first line.\n")
            f.write("And this is the second line.\n")
            f.write("Finally, the third line.\n")
    except Exception as e:
        print(f"Could not create dummy file: {e}")

    read_and_print_file(file_to_read)
# Out:
# This is the first line.
# And this is the second line.
# Finally, the third line.

# %% [markdown]
# 3.	How would you handle a case where the file doesn’t exist while trying to open it for reading?

# %%
try:
    with open("my_file.txt", "r") as file:
        content = file.read()
        print("File content:", content)
except FileNotFoundError:
    print("Error: The file 'my_file.txt' was not found.")
    content = "Default content if file not found"
    print("Using default content:", content)
# Out:
# File content: Hello, Python!

# %% [markdown]
# 4.	Write a python script that reads from one file and writes its content to another file?

# %%
def copy_file_content(source_file, destination_file):

    try:
        with open(source_file, 'r') as infile:
            content = infile.read()

        with open(destination_file, 'w') as outfile:
            outfile.write(content)
        print(f"Content successfully copied from '{source_file}' to '{destination_file}'")

    except FileNotFoundError:
        print(f"Error: The file '{source_file}' was not found.")
    except PermissionError:
        print(f"Error: You don't have permission to access '{source_file}' or create '{destination_file}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage:
source_filename = "source.txt"
destination_filename = "destination.txt"

# Create a sample source file
with open(source_filename, "w") as f:
    f.write("This is the content of the source file.\n")
    f.write("It has multiple lines.\n")

# Call the function to copy the content
copy_file_content(source_filename, destination_filename)

# Verify the content of the destination file
with open(destination_filename, "r") as f:
    print("\nContent of the destination file:")
    print(f.read())
# Out:
# Content successfully copied from 'source.txt' to 'destination.txt'
#
# Content of the destination file:
# This is the content of the source file.
# It has multiple lines.

# %% [markdown]
# 5.	How would you catch and handle division by zero error in python?

# %%
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    print(f"The result is: {result}")
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
    # You can also assign a default value or take other recovery actions here
    result = None
    print(f"Result set to: {result}")
# Out:
# Error: Cannot divide by zero!
# Result set to: None

# %% [markdown]
# 6.	Write a python program that logs an error message to a log file when a division by zero exception occurs.?

# %%
import logging

logging.basicConfig(filename='division_errors.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def safe_division(numerator, denominator):
    """
    Performs division and logs an error if a ZeroDivisionError occurs.
    """
    try:
        result = numerator / denominator
        return result
    except ZeroDivisionError as e:
        # Log the error message to the configured log file
        logging.error(f"Attempted division by zero: {e}")
        return None

# Example usage:
print("Performing division operations...")
result1 = safe_division(10, 2)
if result1 is not None:
    print(f"Result of 10 / 2: {result1}")

result2 = safe_division(5, 0) # This will cause a ZeroDivisionError
if result2 is not None:
    print(f"Result of 5 / 0: {result2}")
else:
    print("Division by zero prevented and logged.")

result3 = safe_division(20, 4)
if result3 is not None:
    print(f"Result of 20 / 4: {result3}")

print("Program finished.")
# Out:
# ERROR:root:Attempted division by zero: division by zero
# Performing division operations...
# Result of 10 / 2: 5.0
# Division by zero prevented and logged.
# Result of 20 / 4: 5.0
# Program finished.

# %% [markdown]
# 7.	How do you log information at different levels (INFO, ERROR, WARNING) in python using the logging module?

# %%
import logging

# Configure basic logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# Log messages at different levels
logging.debug("This message will not be displayed as the level is set to INFO.")
logging.info("Application started successfully.")
logging.warning("Disk space is running low.")
logging.error("Failed to connect to the database.")
logging.critical("System shutdown initiated due to critical error.")
# Out:
# WARNING:root:Disk space is running low.
# ERROR:root:Failed to connect to the database.
# CRITICAL:root:System shutdown initiated due to critical error.

# %% [markdown]
# 8.	Write a program to handle a file opening error using exception handling?

# %%
def read_file_with_exception_handling(filename):

    try:
        with open(filename, 'r') as file:
            content = file.read()
            print(f"File '{filename}' opened successfully. Content:\n{content}")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except IOError as e:
        print(f"Error: An I/O error occurred while opening or reading '{filename}': {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage:
# 1. Attempt to open a file that exists
read_file_with_exception_handling("existing_file.txt")

# 2. Attempt to open a file that does not exist
read_file_with_exception_handling("nonexistent_file.txt")
# Out:
# File 'existing_file.txt' opened successfully. Content:
# This is an existing file.
#
# Error: The file 'nonexistent_file.txt' was not found.

# %% [markdown]
# 9.	How can you read a file line by line and store its content in a list python?

# %%
def read_file_to_list(filename):

    lines = []
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            for line in file:
                lines.append(line.strip())
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    return lines

# Example usage:
file_content = read_file_to_list("my_document.txt")
if file_content:
    print("Content of the file:")
    for line in file_content:
        print(line)
# Out:
# Content of the file:
# This is the first line.
# And this is the second line.
# Finally, the third line.

# %% [markdown]
# 10.	How can you append data to an existing file in python?

# %%
with open("my_file.txt", "a") as file:
    # Write the new data to the file
    file.write("This is a new line of text.\n")
    file.write("Another line to append.\n")

print("Data appended successfully!")
# Out:
# Data appended successfully!

# %% [markdown]
# 11.	Write a python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn’t exist.?

# %%
# Define a sample dictionary
my_dictionary = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

# Key to attempt accessing
key_to_find = "occupation"

try:
    # Attempt to access the key
    value = my_dictionary[key_to_find]
    print(f"Successfully accessed '{key_to_find}': {value}")
except KeyError:
    # Handle the KeyError if the key does not exist
    print(f"Error: The key '{key_to_find}' does not exist in the dictionary.")
    print("Please try accessing an existing key like 'name', 'age', or 'city'.")

# Another example with an existing key
key_to_find_existing = "name"
try:
    value_existing = my_dictionary[key_to_find_existing]
    print(f"\nSuccessfully accessed '{key_to_find_existing}': {value_existing}")
except KeyError:
    print(f"Error: The key '{key_to_find_existing}' does not exist in the dictionary.")
# Out:
# Error: The key 'occupation' does not exist in the dictionary.
# Please try accessing an existing key like 'name', 'age', or 'city'.
#
# Successfully accessed 'name': Alice

# %% [markdown]
# 12.	Write a program that demonstrates using multiple except blocks to handle different types of exceptions.?

# %%
def perform_calculation():
    try:
        # Prompt user for input and attempt to convert it to an integer
        user_input = input("Enter a number: ")
        number = int(user_input)

        # Attempt to perform a division operation
        result = 100 / number
        print(f"Result of division: {result}")

    except ValueError:
        # This block handles exceptions related to invalid input type
        print("Error: Invalid input. Please enter a valid integer.")

    except ZeroDivisionError:
        # This block handles exceptions related to division by zero
        print("Error: Cannot divide by zero. Please enter a non-zero number.")

    except Exception as e:
        # This is a general exception handler for any other unexpected errors
        print(f"An unexpected error occurred: {e}")

# Call the function to demonstrate exception handling
perform_calculation()
# Out:
# Enter a number: 18
# Result of division: 5.555555555555555

# %% [markdown]
# 13.	How would you check if a file exists before attempting to read it in python.?

# %%
import os

file_path = "my_file.txt"

if os.path.exists(file_path):
    # The path exists, but it could be a file or a directory
    if os.path.isfile(file_path):
        print(f"The file '{file_path}' exists and is a regular file.")
        # Attempt to read the file
        try:
            with open(file_path, 'r') as f:
                content = f.read()
                print("File content:", content)
        except Exception as e:
            print(f"Error reading file: {e}")
    else:
        print(f"'{file_path}' exists but is not a regular file (it might be a directory).")
else:
    print(f"The file '{file_path}' does not exist.")
# Out:
# The file 'my_file.txt' exists and is a regular file.
# File content: Hello, Python!This is new content being appended.
# Another line of appended text.
# This is a new line of text.
# Another line to append.
# This is a new line of text.
# Another line to append.

# %% [markdown]
# 14.	Write a program that uses the logging module to log both informational and error messages.?

# %%
import logging

def configure_logger():

    logging.basicConfig(
        filename='application.log',
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )

def perform_operation(value):

    try:
        result = 10 / value
        logging.info(f"Operation successful: 10 divided by {value} is {result}")
    except ZeroDivisionError:
        logging.error("Error: Attempted to divide by zero!")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    configure_logger()

    logging.info("Program started.")

    perform_operation(5)
    perform_operation(0)
    perform_operation(2.5)

    logging.info("Program finished.")
# Out:
# ERROR:root:Error: Attempted to divide by zero!

# %% [markdown]
# 15.	Write a python program that prints the content of a file and handles the case when the file is empty.?

# %%
import os

def print_file_content(filename):

    try:
        with open(filename, 'r') as file:
            content = file.read()
            if len(content) == 0:
                print(f"The file '{filename}' is empty.")
            else:
                print(f"--- Content of '{filename}' ---")
                print(content)
    except FileNotFoundError:
        print(f"Error: The file '{filename}' does not exist.")
    except IOError as e:
        print(f"Error reading file '{filename}': {e}")

file_name = input("Enter the filename: ")
print_file_content(file_name)
# Out:
# Enter the filename: jayanta.
# Error: The file 'jayanta.' does not exist.

# %% [markdown]
# 16.	Demonstrate how to use memory profiling to check the memory usage of a small program.?

# %%
pip install memory_profiler
# Out:
# Collecting memory_profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory_profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory_profiler
# Successfully installed memory_profiler-0.61.0

# %% [markdown]
# 17.	Write a python program to create and write a list of numbers to a file, one number per line.?

# %%
def write_numbers_to_file(filename, number_list):

    try:
        with open(filename, 'w') as file:
            for number in number_list:
                file.write(str(number) + '\n')
        print(f"Numbers successfully written to '{filename}'.")
    except IOError as e:
        print(f"Error writing to file '{filename}': {e}")

if __name__ == "__main__":
    # Create a sample list of numbers
    my_numbers = [10, 25, 30, 45, 60, 75, 90]

    # Specify the output filename
    output_file = "numbers.txt"

    # Call the function to write the numbers to the file
    write_numbers_to_file(output_file, my_numbers)

    # Optional: Verify the content by reading the file
    print("\nContent of the file:")
    try:
        with open(output_file, 'r') as file:
            print(file.read())
    except IOError as e:
        print(f"Error reading file '{output_file}': {e}")
# Out:
# Numbers successfully written to 'numbers.txt'.
#
# Content of the file:
# 10
# 25
# 30
# 45
# 60
# 75
# 90

# %% [markdown]
# 18.	How would you implement a basic logging setup that logs to a file rotation after 1MB.?

# %%
import logging
from logging.handlers import RotatingFileHandler

def setup_rotating_logger(log_file_path="app.log", max_bytes=1024 * 1024, backup_count=5):

    logger = logging.getLogger('my_rotating_logger')
    logger.setLevel(logging.INFO)

    handler = RotatingFileHandler(
        log_file_path,
        maxBytes=max_bytes,
        backupCount=backup_count
    )


    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)

    # Add the handler to the logger
    logger.addHandler(handler)

    return logger

# Example usage:
if __name__ == "__main__":
    logger = setup_rotating_logger()

    for i in range(20000):  # Log many messages to trigger rotation
        logger.info(f"This is log message number {i}")

    logger.info("Logging complete. Check the 'app.log' and rotated files.")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO
# INFO:my_rotating_logger:This is log message number 15138
# INFO:my_rotating_logger:This is log message number 15139
# INFO:my_rotating_logger:This is log message number 15140
# INFO:my_rotating_logger:This is log message number 15141
# INFO:my_rotating_logger:This is log message number 15142
# INFO:my_rotating_logger:This is log message number 15143
# INFO:my_rotating_logger:This is log message number 15144
# INFO:my_rotating_logger:This is log message number 15145
# INFO:my_rotating_logger:This is log message number 15146
# INFO:my_rotating_logger:This is log message number 15147
# INFO:my_rotating_logger:This is log message number 15148
# INFO:my_rotating_logger:This is log message number 15149
# INFO:my_rotating_logger:This is log message number 15150
# INFO:my_rotating_logger:This is log message number 15151
# INFO:my_rotating_logger:This is log message number 15152
# INFO:my_rotating_logger:This is log message number 15153
# INFO:my_rotating_logger:This is log message number 15154
# INFO:my_rotating_logger:This is log message number 15155
# INFO:my_rotating_logger:This is log message number 15156
# INFO:my_rotating_logger:This is log message number 15157
# INFO:my_rotating_logger:This is log message number 15158
# INFO:my_rotating_logger:This is log message number 15159
# INFO:my_rotating_logger:This is log message number 15160
# INFO:my_rotating_logger:This is log message number 15161
# INFO:my_rotating_logger:This is log message number 15162
# INFO:my_rotating_logger:This is log message number 15163
# INFO:my_rotating_logger:This is log message number 15164
# INFO:my_rotating_logger:This is log message number 15165
# INFO:my_rotating_logger:This is log message number 15166
# INFO:my_rotating_logger:This is log message number 15167
# INFO:my_rotating_logger:This is log message number 15168
# INFO:my_rotating_logger:This is log message number 15169
# INFO:my_rotating_logger:This is log message number 15170
# INFO:my_rotating_logger:This is log message number 15171
# INFO:my_rotating_logger:This is log message number 15172
# INFO:my_rotating_logger:This is log message number 15173
# INFO:my_rotating_logger:This is log message number 15174
# INFO:my_rotating_logger:This is log message number 15175
# INFO:my_rotating_logger:This is log message number 15176
# INFO:my_rotating_logger:This is log message number 15177
# INFO:my_rotating_logger:This is log message number 15178
# INFO:my_rotating_logger:This is log message number 15179
# INFO:my_rotating_logger:This is log message number 15180
# INFO:my_rotating_logger:This is log message number 15181
# INFO:my_rotating_logger:This is log message number 15182
# INFO:my_rotating_logger:This is log message number 15183
# INFO:my_rotating_logger:This is log message number 15184
# INFO:my_rotating_logger:This is log message number 15185
# INFO:my_rotating_logger:This is log message number 15186
# INFO:my_rotating_logger:This is log message number 15187
# INFO:my_rotating_logger:This is log message number 15188
# INFO:my_rotating_logger:This is log message number 15189
# INFO:my_rotating_logger:This is log message number 15190
# INFO:my_rotating_logger:This is log message number 15191
# INFO:my_rotating_logger:This is log message number 15192
# INFO:my_rotating_logger:This is log message number 15193
# INFO:my_rotating_logger:This is log message number 15194
# INFO:my_rotating_logger:This is log message number 15195
# INFO:my_rotating_logger:This is log message number 15196
# INFO:my_rotating_logger:This is log message number 15197
# INFO:my_rotating_logger:This is log message number 15198
# INFO:my_rotating_logger:This is log message number 15199
# INFO:my_rotating_logger:This is log message number 15200
# INFO:my_rotating_logger:This is log message number 15201
# INFO:my_rotating_logger:This is log message number 15202
# INFO:my_rotating_logger:This is log message number 15203
# INFO:my_rotating_logger:This is log message number 15402
# INFO:my_rotating_logger:This is log message number 15403
# INFO:my_rotating_logger:This is log message number 15404
# INFO:my_rotating_logger:This is log message number 15405
# INFO:my_rotating_logger:This is log message number 15406
# INFO:my_rotating_logger:This is log message number 15407
# INFO:my_rotating_logger:This is log message number 15408
# INFO:my_rotating_logger:This is log message number 15409
# INFO:my_rotating_logger:This is log message number 15410
# INFO:my_rotating_logger:This is log message number 15411
# INFO:my_rotating_logger:This is log message number 15412
# INFO:my_rotating_logger:This is log message number 15413
# INFO:my_rotating_logger:This is log message number 15414
# INFO:my_rotating_logger:This is log message number 15415
# INFO:my_rotating_logger:This is log message number 15416
# INFO:my_rotating_logger:This is log message number 15417
# INFO:my_rotating_logger:This is log message number 15418
# INFO:my_rotating_logger:This is log message number 15419
# INFO:my_rotating_logger:This is log message number 15420
# INFO:my_rotating_logger:This is log message number 15421
# INFO:my_rotating_logger:This is log message number 15422
# INFO:my_rotating_logger:This is log message number 15423
# INFO:my_rotating_logger:This is log message number 15424
# INFO:my_rotating_logger:This is log message number 15425
# INFO:my_rotating_logger:This is log message number 15426
# INFO:my_rotating_logger:This is log message number 15427
# INFO:my_rotating_logger:This is log message number 15428
# INFO:my_rotating_logger:This is log message number 15429
# INFO:my_rotating_logger:This is log message number 15430
# INFO:my_rotating_logger:This is log message number 15431
# INFO:my_rotating_logger:This is log message number 15432
# INFO:my_rotating_logger:This is log message number 15433
# INFO:my_rotating_logger:This is log message number 15434
# INFO:my_rotating_logger:This is log message number 15435
# INFO:my_rotating_logger:This is log message number 15436
# INFO:my_rotating_logger:This is log message number 15437
# INFO:my_rotating_logger:This is log message number 15438
# INFO:my_rotating_logger:This is log message number 15439
# INFO:my_rotating_logger:This is log message number 15440
# INFO:my_rotating_logger:This is log message number 15441
# INFO:my_rotating_logger:This is log message number 15442
# INFO:my_rotating_logger:This is log message number 15443
# INFO:my_rotating_logger:This is log message number 15444
# INFO:my_rotating_logger:This is log message number 15445
# INFO:my_rotating_logger:This is log message number 15446
# INFO:my_rotating_logger:This is log message number 15447
# INFO:my_rotating_logger:This is log message number 15448
# INFO:my_rotating_logger:This is log message number 15449
# INFO:my_rotating_logger:This is log message number 15450
# INFO:my_rotating_logger:This is log message number 15451
# INFO:my_rotating_logger:This is log message number 15452
# INFO:my_rotating_logger:This is log message number 15453
# INFO:my_rotating_logger:This is log message number 15454
# INFO:my_rotating_logger:This is log message number 15455
# INFO:my_rotating_logger:This is log message number 15456
# INFO:my_rotating_logger:This is log message number 15457
# INFO:my_rotating_logger:This is log message number 15458
# INFO:my_rotating_logger:This is log message number 15459
# INFO:my_rotating_logger:This is log message number 15460
# INFO:my_rotating_logger:This is log message number 15461
# INFO:my_rotating_logger:This is log message number 15462
# INFO:my_rotating_logger:This is log message number 15463
# INFO:my_rotating_logger:This is log message number 15464
# INFO:my_rotating_logger:This is log message number 15465
# INFO:my_rotating_logger:This is log message number 15466
# INFO:my_rotating_logger:This is log message number 15467
# INFO:my_rotating_logger:This is log message number 15600
# INFO:my_rotating_logger:This is log message number 15601
# INFO:my_rotating_logger:This is log message number 15602
# INFO:my_rotating_logger:This is log message number 15603
# INFO:my_rotating_logger:This is log message number 15604
# INFO:my_rotating_logger:This is log message number 15605
# INFO:my_rotating_logger:This is log message number 15606
# INFO:my_rotating_logger:This is log message number 15607
# INFO:my_rotating_logger:This is log message number 15608
# INFO:my_rotating_logger:This is log message number 15609
# INFO:my_rotating_logger:This is log message number 15610
# INFO:my_rotating_logger:This is log message number 15611
# INFO:my_rotating_logger:This is log message number 15612
# INFO:my_rotating_logger:This is log message number 15613
# INFO:my_rotating_logger:This is log message number 15614
# INFO:my_rotating_logger:This is log message number 15615
# INFO:my_rotating_logger:This is log message number 15616
# INFO:my_rotating_logger:This is log message number 15617
# INFO:my_rotating_logger:This is log message number 15618
# INFO:my_rotating_logger:This is log message number 15619
# INFO:my_rotating_logger:This is log message number 15620
# INFO:my_rotating_logger:This is log message number 15621
# INFO:my_rotating_logger:This is log message number 15622
# INFO:my_rotating_logger:This is log message number 15623
# INFO:my_rotating_logger:This is log message number 15624
# INFO:my_rotating_logger:This is log message number 15625
# INFO:my_rotating_logger:This is log message number 15626
# INFO:my_rotating_logger:This is log message number 15627
# INFO:my_rotating_logger:This is log message number 15628
# INFO:my_rotating_logger:This is log message number 15629
# INFO:my_rotating_logger:This is log message number 15630
# INFO:my_rotating_logger:This is log message number 15631
# INFO:my_rotating_logger:This is log message number 15632
# INFO:my_rotating_logger:This is log message number 15633
# INFO:my_rotating_logger:This is log message number 15634
# INFO:my_rotating_logger:This is log message number 15635
# INFO:my_rotating_logger:This is log message number 15636
# INFO:my_rotating_logger:This is log message number 15637
# INFO:my_rotating_logger:This is log message number 15638
# INFO:my_rotating_logger:This is log message number 15639
# INFO:my_rotating_logger:This is log message number 15640
# INFO:my_rotating_logger:This is log message number 15641
# INFO:my_rotating_logger:This is log message number 15642
# INFO:my_rotating_logger:This is log message number 15643
# INFO:my_rotating_logger:This is log message number 15644
# INFO:my_rotating_logger:This is log message number 15645
# INFO:my_rotating_logger:This is log message number 15646
# INFO:my_rotating_logger:This is log message number 15647
# INFO:my_rotating_logger:This is log message number 15648
# INFO:my_rotating_logger:This is log message number 15649
# INFO:my_rotating_logger:This is log message number 15650
# INFO:my_rotating_logger:This is log message number 15651
# INFO:my_rotating_logger:This is log message number 15652
# INFO:my_rotating_logger:This is log message number 15653
# INFO:my_rotating_logger:This is log message number 15654
# INFO:my_rotating_logger:This is log message number 15655
# INFO:my_rotating_logger:This is log message number 15656
# INFO:my_rotating_logger:This is log message number 15657
# INFO:my_rotating_logger:This is log message number 15658
# INFO:my_rotating_logger:This is log message number 15659
# INFO:my_rotating_logger:This is log message number 15660
# INFO:my_rotating_logger:This is log message number 15661
# INFO:my_rotating_logger:This is log message number 15662
# INFO:my_rotating_logger:This is log message number 15663
# INFO:my_rotating_logger:This is log message number 15664
# INFO:my_rotating_logger:This is log message number 15665
# INFO:my_rotating_logger:This is log message number 15666
# INFO:my_rotating_logger:This is log message number 15667
# INFO:my_rotating_logger:This is log message number 15668
# INFO:my_rotating_logger:This is log message number 15669
# INFO:my_rotating_logger:This is log message number 15670
# INFO:my_rotating_logger:This is log message number 15671
# INFO:my_rotating_logger:This is log message number 15672
# INFO:my_rotating_logger:This is log message number 15673
# INFO:my_rotating_logger:This is log message number 15674
# INFO:my_rotating_logger:This is log message number 15675
# INFO:my_rotating_logger:This is log message number 15676
# INFO:my_rotating_logger:This is log message number 15677
# INFO:my_rotating_logger:This is log message number 15678
# INFO:my_rotating_logger:This is log message number 15679
# INFO:my_rotating_logger:This is log message number 15680
# INFO:my_rotating_logger:This is log message number 15681
# INFO:my_rotating_logger:This is log message number 15682
# INFO:my_rotating_logger:This is log message number 15683
# INFO:my_rotating_logger:This is log message number 15684
# INFO:my_rotating_logger:This is log message number 15685
# INFO:my_rotating_logger:This is log message number 15686
# INFO:my_rotating_logger:This is log message number 15687
# INFO:my_rotating_logger:This is log message number 15688
# INFO:my_rotating_logger:This is log message number 15689
# INFO:my_rotating_logger:This is log message number 15690
# INFO:my_rotating_logger:This is log message number 15691
# INFO:my_rotating_logger:This is log message number 15692
# INFO:my_rotating_logger:This is log message number 15693
# INFO:my_rotating_logger:This is log message number 15694
# INFO:my_rotating_logger:This is log message number 15695
# INFO:my_rotating_logger:This is log message number 15696
# INFO:my_rotating_logger:This is log message number 15697
# INFO:my_rotating_logger:This is log message number 15698
# INFO:my_rotating_logger:This is log message number 15699
# INFO:my_rotating_logger:This is log message number 15700
# INFO:my_rotating_logger:This is log message number 15701
# INFO:my_rotating_logger:This is log message number 15702
# INFO:my_rotating_logger:This is log message number 15703
# INFO:my_rotating_logger:This is log message number 15704
# INFO:my_rotating_logger:This is log message number 15705
# INFO:my_rotating_logger:This is log message number 15706
# INFO:my_rotating_logger:This is log message number 15707
# INFO:my_rotating_logger:This is log message number 15708
# INFO:my_rotating_logger:This is log message number 15709
# INFO:my_rotating_logger:This is log message number 15710
# INFO:my_rotating_logger:This is log message number 15711
# INFO:my_rotating_logger:This is log message number 15712
# INFO:my_rotating_logger:This is log message number 15713
# INFO:my_rotating_logger:This is log message number 15714
# INFO:my_rotating_logger:This is log message number 15715
# INFO:my_rotating_logger:This is log message number 15716
# INFO:my_rotating_logger:This is log message number 15717
# INFO:my_rotating_logger:This is log message number 15718
# INFO:my_rotating_logger:This is log message number 15719
# INFO:my_rotating_logger:This is log message number 15720
# INFO:my_rotating_logger:This is log message number 15721
# INFO:my_rotating_logger:This is log message number 15722
# INFO:my_rotating_logger:This is log message number 15723
# INFO:my_rotating_logger:This is log message number 15724
# INFO:my_rotating_logger:This is log message number 15725
# INFO:my_rotating_logger:This is log message number 15726
# INFO:my_rotating_logger:This is log message number 15727
# INFO:my_rotating_logger:This is log message number 15728
# INFO:my_rotating_logger:This is log message number 15729
# INFO:my_rotating_logger:This is log message number 15730
# INFO:my_rotating_logger:This is log message number 15731
# INFO:my_rotating_logger:This is log message number 15732
# INFO:my_rotating_logger:This is log message number 15799
# INFO:my_rotating_logger:This is log message number 15800
# INFO:my_rotating_logger:This is log message number 15801
# INFO:my_rotating_logger:This is log message number 15802
# INFO:my_rotating_logger:This is log message number 15803
# INFO:my_rotating_logger:This is log message number 15804
# INFO:my_rotating_logger:This is log message number 15805
# INFO:my_rotating_logger:This is log message number 15806
# INFO:my_rotating_logger:This is log message number 15807
# INFO:my_rotating_logger:This is log message number 15808
# INFO:my_rotating_logger:This is log message number 15809
# INFO:my_rotating_logger:This is log message number 15810
# INFO:my_rotating_logger:This is log message number 15811
# INFO:my_rotating_logger:This is log message number 15812
# INFO:my_rotating_logger:This is log message number 15813
# INFO:my_rotating_logger:This is log message number 15814
# INFO:my_rotating_logger:This is log message number 15815
# INFO:my_rotating_logger:This is log message number 15816
# INFO:my_rotating_logger:This is log message number 15817
# INFO:my_rotating_logger:This is log message number 15818
# INFO:my_rotating_logger:This is log message number 15819
# INFO:my_rotating_logger:This is log message number 15820
# INFO:my_rotating_logger:This is log message number 15821
# INFO:my_rotating_logger:This is log message number 15822
# INFO:my_rotating_logger:This is log message number 15823
# INFO:my_rotating_logger:This is log message number 15824
# INFO:my_rotating_logger:This is log message number 15825
# INFO:my_rotating_logger:This is log message number 15826
# INFO:my_rotating_logger:This is log message number 15827
# INFO:my_rotating_logger:This is log message number 15828
# INFO:my_rotating_logger:This is log message number 15829
# INFO:my_rotating_logger:This is log message number 15830
# INFO:my_rotating_logger:This is log message number 15831
# INFO:my_rotating_logger:This is log message number 15832
# INFO:my_rotating_logger:This is log message number 15833
# INFO:my_rotating_logger:This is log message number 15834
# INFO:my_rotating_logger:This is log message number 15835
# INFO:my_rotating_logger:This is log message number 15836
# INFO:my_rotating_logger:This is log message number 15837
# INFO:my_rotating_logger:This is log message number 15838
# INFO:my_rotating_logger:This is log message number 15839
# INFO:my_rotating_logger:This is log message number 15840
# INFO:my_rotating_logger:This is log message number 15841
# ...
# INFO:my_rotating_logger:This is log message number 19721
# INFO:my_rotating_logger:This is log message number 19722
# INFO:my_rotating_logger:This is log message number 19723
# INFO:my_rotating_logger:This is log message number 19724
# INFO:my_rotating_logger:This is log message number 19725
# INFO:my_rotating_logger:This is log message number 19726
# INFO:my_rotating_logger:This is log message number 19727
# INFO:my_rotating_logger:This is log message number 19728
# INFO:my_rotating_logger:This is log message number 19729
# INFO:my_rotating_logger:This is log message number 19730
# INFO:my_rotating_logger:This is log message number 19731
# INFO:my_rotating_logger:This is log message number 19732
# INFO:my_rotating_logger:This is log message number 19733
# INFO:my_rotating_logger:This is log message number 19734
# INFO:my_rotating_logger:This is log message number 19735
# INFO:my_rotating_logger:This is log message number 19736
# INFO:my_rotating_logger:This is log message number 19737
# INFO:my_rotating_logger:This is log message number 19738
# INFO:my_rotating_logger:This is log message number 19739
# INFO:my_rotating_logger:This is log message number 19740
# INFO:my_rotating_logger:This is log message number 19741
# INFO:my_rotating_logger:This is log message number 19742
# INFO:my_rotating_logger:This is log message number 19743
# INFO:my_rotating_logger:This is log message number 19942
# INFO:my_rotating_logger:This is log message number 19943
# INFO:my_rotating_logger:This is log message number 19944
# INFO:my_rotating_logger:This is log message number 19945
# INFO:my_rotating_logger:This is log message number 19946
# INFO:my_rotating_logger:This is log message number 19947
# INFO:my_rotating_logger:This is log message number 19948
# INFO:my_rotating_logger:This is log message number 19949
# INFO:my_rotating_logger:This is log message number 19950
# INFO:my_rotating_logger:This is log message number 19951
# INFO:my_rotating_logger:This is log message number 19952
# INFO:my_rotating_logger:This is log message number 19953
# INFO:my_rotating_logger:This is log message number 19954
# INFO:my_rotating_logger:This is log message number 19955
# INFO:my_rotating_logger:This is log message number 19956
# INFO:my_rotating_logger:This is log message number 19957
# INFO:my_rotating_logger:This is log message number 19958
# INFO:my_rotating_logger:This is log message number 19959
# INFO:my_rotating_logger:This is log message number 19960
# INFO:my_rotating_logger:This is log message number 19961
# INFO:my_rotating_logger:This is log message number 19962
# INFO:my_rotating_logger:This is log message number 19963
# INFO:my_rotating_logger:This is log message number 19964
# INFO:my_rotating_logger:This is log message number 19965
# INFO:my_rotating_logger:This is log message number 19966
# INFO:my_rotating_logger:This is log message number 19967
# INFO:my_rotating_logger:This is log message number 19968
# INFO:my_rotating_logger:This is log message number 19969
# INFO:my_rotating_logger:This is log message number 19970
# INFO:my_rotating_logger:This is log message number 19971
# INFO:my_rotating_logger:This is log message number 19972
# INFO:my_rotating_logger:This is log message number 19973
# INFO:my_rotating_logger:This is log message number 19974
# INFO:my_rotating_logger:This is log message number 19975
# INFO:my_rotating_logger:This is log message number 19976
# INFO:my_rotating_logger:This is log message number 19977
# INFO:my_rotating_logger:This is log message number 19978
# INFO:my_rotating_logger:This is log message number 19979
# INFO:my_rotating_logger:This is log message number 19980
# INFO:my_rotating_logger:This is log message number 19981
# INFO:my_rotating_logger:This is log message number 19982
# INFO:my_rotating_logger:This is log message number 19983
# INFO:my_rotating_logger:This is log message number 19984
# INFO:my_rotating_logger:This is log message number 19985
# INFO:my_rotating_logger:This is log message number 19986
# INFO:my_rotating_logger:This is log message number 19987
# INFO:my_rotating_logger:This is log message number 19988
# INFO:my_rotating_logger:This is log message number 19989
# INFO:my_rotating_logger:This is log message number 19990
# INFO:my_rotating_logger:This is log message number 19991
# INFO:my_rotating_logger:This is log message number 19992
# INFO:my_rotating_logger:This is log message number 19993
# INFO:my_rotating_logger:This is log message number 19994
# INFO:my_rotating_logger:This is log message number 19995
# INFO:my_rotating_logger:This is log message number 19996
# INFO:my_rotating_logger:This is log message number 19997
# INFO:my_rotating_logger:This is log message number 19998
# INFO:my_rotating_logger:This is log message number 19999
# INFO:my_rotating_logger:Logging complete. Check the 'app.log' and rotated files.

# %% [markdown]
# 19. Write a program that handles both indexError and keyError using a try-except block.?

# %%
def access_data(data_source, key_or_index):
    try:
        if isinstance(data_source, list):

            result = data_source[key_or_index]
            print(f"Accessed list element: {result}")
        elif isinstance(data_source, dict):

            result = data_source[key_or_index]
            print(f"Accessed dictionary value: {result}")
        else:
            print("Unsupported data source type.")
    except (IndexError, KeyError) as e:
        print(f"An error occurred: {type(e).__name__} - {e}")

# Example Usage:

# Handling IndexError
my_list = [10, 20, 30]
print("\n--- Testing IndexError ---")
access_data(my_list, 1)  # Valid index
access_data(my_list, 5)  # Invalid index

# Handling KeyError
my_dict = {"name": "Alice", "age": 30}
print("\n--- Testing KeyError ---")
access_data(my_dict, "name")  # Valid key
access_data(my_dict, "city")  # Invalid key

# Handling with an unsupported data type
print("\n--- Testing Unsupported Type ---")
access_data("hello", 0)
# Out:
# --- Testing IndexError ---
# Accessed list element: 20
# An error occurred: IndexError - list index out of range
#
# --- Testing KeyError ---
# Accessed dictionary value: Alice
# An error occurred: KeyError - 'city'
#
# --- Testing Unsupported Type ---
# Unsupported data source type.

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in python?

# %%
# Create a dummy file for the example
with open("my_file.txt", "w") as f:
    f.write("This is the first line.\n")
    f.write("This is the second line.\n")

# Open and read the file using a context manager
with open("my_file.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# This is the first line.
# This is the second line.

# %% [markdown]
# 21. Write a python program that reads a file and prints the number of occurrences of a specific word.?

# %%
def count_word_occurrences(filepath, target_word):

    count = 0
    try:
        with open(filepath, 'r', encoding='utf-8') as file:
            for line in file:

                words = line.lower().split()

                count += words.count(target_word.lower())
    except FileNotFoundError:
        print(f"Error: The file '{filepath}' was not found.")
        return -1  # Indicate an error
    except Exception as e:
        print(f"An error occurred: {e}")
        return -1

    return count

# Example usage:
file_to_analyze = "sample.txt"  # Replace with your file path
word_to_find = "python"

# Create a sample file for demonstration
with open(file_to_analyze, 'w', encoding='utf-8') as f:
    f.write("Python is a great programming language.\n")
    f.write("Learn Python for data science.\n")
    f.write("Python projects are fun.\n")

occurrences = count_word_occurrences(file_to_analyze, word_to_find)

if occurrences != -1:
    print(f"The word '{word_to_find}' appears {occurrences} times in '{file_to_analyze}'.")
# Out:
# The word 'python' appears 3 times in 'sample.txt'.

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents.?

# %%
import os

def is_file_empty(file_path):
    try:
        return os.path.getsize(file_path) == 0
    except OSError:
        # Handle cases where the file doesn't exist or is inaccessible
        return False

# Usage
file_path = "your_file.txt"
if is_file_empty(file_path):
    print(f"The file '{file_path}' is empty.")
else:
    print(f"The file '{file_path}' is not empty, proceeding to read.")
    # Read the file contents here
# Out:
# The file 'your_file.txt' is not empty, proceeding to read.

# %% [markdown]
# 23. Write a python program that writes to a log file when an error occurs during the handling.?

# %%
import logging
logging.basicConfig(
    filename='error_log.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def perform_risky_operation(data):

    try:
        result = 10 / data
        print(f"Operation successful: {result}")
    except ZeroDivisionError:
        logging.error("Attempted to divide by zero.")
    except TypeError:
        logging.error("Invalid data type provided for division.")
    except Exception as e:

        logging.error(f"An unexpected error occurred: {e}")

# Example usage:
perform_risky_operation(5)
perform_risky_operation(0)
perform_risky_operation("text")
# Out:
# ERROR:root:Attempted to divide by zero.
# ERROR:root:Invalid data type provided for division.
# Operation successful: 2.0
